# %% [markdown]
# # CCPI Report and Paul Tobin Combined Data

# %%
import pandas as pd #database management
import numpy as np #numerical functions
import matplotlib as mpl #data visualizations
import matplotlib.pyplot as plt #additional functionality for matplotlib
from scipy import stats #statistical toolset

# %%
import os
os.getcwd() #view current working directory
# Out:
# 'C:\\Users\\hunta\\IBEI Dissertation'

# %%
Data = pd.read_csv(r"C:\Users\hunta\IBEI Dissertation\CCPI_Tobin_Plus Inequality (Combined Data) - Copy.csv", index_col = 0)

Data = Data.drop('Unnamed: 1', axis = 1)

pd.DataFrame(Data)

Data
# Out:
#                   Country  Climate Score  Policy Score  Inequality OWID  \
# Rank
# 55         Australia 2019          31.27          11.8               34
# 36           Austria 2019          48.78          41.2               28
# 31           Belgium 2019          50.63          63.4               27
# 54            Canada 2019          34.26          57.7               32
# 15           Denmark 2019          61.96          52.1               25
# 13           Finland 2019          62.61          80.1               26
# 21            France 2019          59.30          90.9               29
# 27           Germany 2019          55.18          72.4               29
# 30            Greece 2019          50.86          26.5               34
# 48           Ireland 2019          40.84          36.7               31
# 23             Italy 2019          58.69          55.5               33
# 49             Japan 2019          40.63          38.2               33
# ...

# %%
Data.describe()
# Out:
#        Climate Score  Policy Score  Inequality OWID  OECD Inequality  \
# count      22.000000     22.000000        22.000000        22.000000
# mean       52.381818     59.227273        30.772727         0.308636
# std        13.297636     26.683920         3.791366         0.034306
# min        18.820000      0.000000        25.000000         0.262000
# 25%        45.652500     39.775000        28.000000         0.284250
# 50%        54.645000     60.550000        30.500000         0.300500
# 75%        61.605000     81.300000        33.750000         0.332500
# max        76.280000     98.400000        39.000000         0.391000
#
#        Ambitious Climate Policy (ambclimpol)  Left-Wing Government (leftgov)  \
# count                              22.000000                       22.000000
# mean                                0.527273                        0.352273
# std                                 0.395609                        0.258824
# ...

# %%
summary = Data.describe()

summary = summary.transpose()

summary.head()
# Out:
#                                        count       mean        std     min  \
# Climate Score                           22.0  52.381818  13.297636  18.820
# Policy Score                            22.0  59.227273  26.683920   0.000
# Inequality OWID                         22.0  30.772727   3.791366  25.000
# OECD Inequality                         22.0   0.308636   0.034306   0.262
# Ambitious Climate Policy (ambclimpol)   22.0   0.527273   0.395609   0.000
#
#                                             25%      50%      75%     max
# Climate Score                          45.65250  54.6450  61.6050  76.280
# Policy Score                           39.77500  60.5500  81.3000  98.400
# Inequality OWID                        28.00000  30.5000  33.7500  39.000
# OECD Inequality                         0.28425   0.3005   0.3325   0.391
# Ambitious Climate Policy (ambclimpol)   0.19500   0.4550   0.9825   1.000

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
import seaborn as sns; sns.set(color_codes=True) #more visualization functions
import statsmodels.api as sm

# %%
X = Data[['OECD Inequality']]
Y = Data['Climate Score']

lm.fit(X, Y)

Yhat = lm.predict(X)

sns.regplot(X, Y, data = Data)

plt.ylim(0, )
plt.xlabel('Income Inequality', fontsize = 13)
plt.ylabel('Climate Score', fontsize = 13)
plt.title('Climate Score vs Inequality', fontsize = 15)

plt.savefig(r"C:\Users\hunta\OneDrive\Desktop\Dissertation\Data\Data Analysis Images\Climate Score_Inequality.png")

# %%
X = Data[['OECD Inequality']]
Y = Data['Policy Score']

lm.fit(X, Y)

Yhat = lm.predict(X)

sns.regplot(X, Y, data = Data)

plt.ylim(0, )
plt.xlabel('Income Inequality', fontsize = 13)
plt.ylabel('Policy Score', fontsize = 13)
plt.title('Policy Score vs Inequality', fontsize = 15)

plt.savefig(r"C:\Users\hunta\OneDrive\Desktop\Dissertation\Data\Data Analysis Images\Policy Score_Inequality.png")

# %%
X = Data[['Policy Score']]
Y = Data['Climate Score']

lm.fit(X, Y)

Yhat = lm.predict(X)

plot1 = (sns.regplot(X, Y, data = Data),

plt.ylim(0, ),
plt.xlabel('Policy Score', fontsize = 13),
plt.ylabel('Climate Score', fontsize = 13),
plt.title('Climate Score vs Policy Score', fontsize = 15))

# %%
X = Data[['Climate Score']]
Y = Data['Ambitious Climate Policy (ambclimpol)']

lm.fit(X, Y)

Yhat = lm.predict(X)

sns.regplot(X, Y, data = Data)

plt.xlabel('Climate Score', fontsize = 13)
plt.ylabel('Ambitious Climate Policy', fontsize = 13)
plt.title('Ambitious Climate Policy vs Climate Score', fontsize = 15)

plt.ylim(0, )
# Out:
# (0, 1.370108618976577)

# %%
X = Data[['EU Membership (eumember)']]
Y = Data['OECD Inequality']

lm.fit(X, Y)

Yhat = lm.predict(X)

sns.regplot(X, Y, data = Data)

plt.xlabel('EU Membership', fontsize = 13)
plt.ylabel('Income Inequality', fontsize = 13)
plt.title('Income Inequality vs EU Membership', fontsize = 15)

plt.ylim(0, )
# Out:
# (0, 0.3979652455849889)

# %%
X = Data[['OECD Inequality']]
Y = Data['EU Membership (eumember)']

lm.fit(X, Y)

Yhat = lm.predict(X)

sns.regplot(X, Y, data = Data)

plt.xlabel('Income Inequality', fontsize = 13)
plt.ylabel('EU Membership', fontsize = 13)
plt.title('EU Membership vs Income Inequality', fontsize = 15)

plt.ylim(0, )

plt.savefig(r"C:\Users\hunta\OneDrive\Desktop\Dissertation\Data\Data Analysis Images\EU_Inequality.png")

# %%
X = Data[['OECD Inequality']]
Y = Data['Ambitious Climate Policy (ambclimpol)']

lm.fit(X, Y)

Yhat = lm.predict(X)

sns.regplot(X, Y, data = Data)

plt.xlabel('Income Inequality', fontsize = 13)
plt.ylabel('Ambitious Climate Policy', fontsize = 13)
plt.title('Ambitious Climate Change Policy vs Income Inequality', fontsize = 15)

plt.ylim(0, )

plt.savefig(r"C:\Users\hunta\OneDrive\Desktop\Dissertation\Data\Data Analysis Images\Ambitious Policy_Inequality.png")

# %%
X = Data[['EU Membership (eumember)']]
Y = Data['Ambitious Climate Policy (ambclimpol)']

lm.fit(X, Y)

Yhat = lm.predict(X)

sns.regplot(X, Y, data = Data)

plt.xlabel('EU Membership', fontsize = 13)
plt.ylabel('Ambitious Climate Policy', fontsize = 13)
plt.title('Ambitious Climate Policy vs EU Membership', fontsize = 15)

plt.ylim(0, )

plt.savefig(r"C:\Users\hunta\OneDrive\Desktop\Dissertation\Data\Data Analysis Images\Ambitious Policy_EU Membership.png")

# %%
X = Data[['EU Membership (eumember)']]
Y = Data['Climate Score']

lm.fit(X, Y)

Yhat = lm.predict(X)

sns.regplot(X, Y, data = Data)

plt.xlabel('EU Membership', fontsize = 13)
plt.ylabel('Climate Score', fontsize = 13)
plt.title('Climate Score vs EU Membership', fontsize = 15)

plt.ylim(0, )

plt.savefig(r"C:\Users\hunta\OneDrive\Desktop\Dissertation\Data\Data Analysis Images\Climate Score_EU Membership.png")

# %%
X = Data[['EU Membership (eumember)']]
Y = Data['Policy Score']

lm.fit(X, Y)

Yhat = lm.predict(X)

sns.regplot(X, Y, data = Data)

plt.ylim(0, )
plt.xlabel('EU Membership', fontsize = 13)
plt.ylabel('Policy Score', fontsize = 13)
plt.title('Policy Score vs EU Membership', fontsize = 15)

plt.savefig(r"C:\Users\hunta\OneDrive\Desktop\Dissertation\Data\Data Analysis Images\Policy Score_EU Membership.png")
